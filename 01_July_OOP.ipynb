# %% [markdown]
# 1. What is the primary goal of Object-Oriented Programming (OOP)?
# Answer: Primary goal is to hold entire data into a single object such

# %% [markdown]
# 2. What is an object in Python?
# Answer: Object is an instance of a class which defines its characteristics

# %% [markdown]
# 3. What is a class in Python?
# Answer: A class is a code template for creating objects. A class serves as a blueprint for creating objects, providing the initial values for state (i.e., properties or attributes) and implementations of behavior (i.e., functions or methods).

# %% [markdown]
# 4. What are attributes and methods in a class?
# A class serves as a blueprint for creating objects (instances of the class). Attributes hold data about an instance of the class and define its state. Methods are functions defined within a class and are used to define the behaviors of an object.

# %% [markdown]
# 5. What is the difference between class variables and instance variables in Python?
# Answer: Class variables are shared across all instances of a class, while instance variables are unique to each instance.

# %% [markdown]
#  6. What is the purpose of the self parameter in Python class methods?
# Answer: The self parameter is a reference to the current instance of the class, and is used to access variables that belong to the class. It’s a convention not a keyword.

# %% [markdown]
# ###7. For a library management system, you have to design the "Book" class with OOP principles in mind. The “Book” class will have following attributes:
# a. title: Represents the title of the book.
# b. author: Represents the author(s) of the book.
# c. isbn: Represents the ISBN (International Standard Book Number) of the book. d. publication_year: Represents the year of publication of the book. e. available_copies: Represents the number of copies available for checkout. The class will also include the following methods:
# a. check_out(self): Decrements the available copies by one if there are copies available for checkout.
# b. return_book(self): Increments the available copies by one when a book is returned.
# c. display_book_info(self): Displays the information about the book, including its attributes and the number of available copies.
#
#
# Answer:

# %%
   
class Book:
    def __init__(self, title, author, isbn, publication_year, available_copies):
        """
        Initializes a new instance of the Book class.

        :param title: str - The title of the book
        :param author: str - The author(s) of the book
        :param isbn: str - The International Standard Book Number of the book
        :param publication_year: int - The year of publication of the book
        :param available_copies: int - The number of copies available for checkout
        """
        self.title = title
        self.author = author
        self.isbn = isbn
        self.publication_year = publication_year
        self.available_copies = available_copies

    def check_out(self):
        """
        Decrements the available copies of the book by one, if there are copies available.
        """
        if self.available_copies > 0:
            self.available_copies -= 1
            print(f"One copy checked out. {self.available_copies} copies remaining.")
        else:
            print("No copies available to check out.")

    def return_book(self):
        """
        Increments the available copies of the book by one upon return.
        """
        self.available_copies += 1
        print(f"One copy returned. {self.available_copies} copies now available.")

    def display_book_info(self):
        """
        Displays the information about the book.
        """
        info = (
            f"Title: {self.title}\n"
            f"Author: {self.author}\n"
            f"ISBN: {self.isbn}\n"
            f"Publication Year: {self.publication_year}\n"
            f"Available Copies: {self.available_copies}"
        )
        print(info)

# Example usage:
if __name__ == "__main__":
    # Creating a book instance
    book1 = Book("1984", "George Orwell", "9780451524935", 1949, 5)
    
    # Display book information
    book1.display_book_info()
    
    # Check out a book
    book1.check_out()
    
    # Display book information
    book1.display_book_info()
    
    # Return a book
    book1.return_book()
    
    # Display book information
    book1.display_book_info()
# Out:
# Title: 1984
# Author: George Orwell
# ISBN: 9780451524935
# Publication Year: 1949
# Available Copies: 5
# One copy checked out. 4 copies remaining.
# Title: 1984
# Author: George Orwell
# ISBN: 9780451524935
# Publication Year: 1949
# Available Copies: 4
# One copy returned. 5 copies now available.
# Title: 1984
# Author: George Orwell
# ISBN: 9780451524935
# Publication Year: 1949
# Available Copies: 5

# %% [markdown]
# 8. For a ticket booking system, you have to design the "Ticket" class with OOP principles in mind. The “Ticket” class should have the following attributes: a. ticket_id: Represents the unique identifier for the ticket.
# b. event_name: Represents the name of the event.
# c. event_date: Represents the date of the event.
# d. venue: Represents the venue of the event.
# e. seat_number: Represents the seat number associated with the ticket. f. price: Represents the price of the ticket.
# g. is_reserved: Represents the reservation status of the ticket.
# The class also includes the following methods:
# a. reserve_ticket(self): Marks the ticket as reserved if it is not already reserved. b. cancel_reservation(self): Cancels the reservation of the ticket if it is already reserved.
# c. display_ticket_info(self): Displays the information about the ticket, including its attributes and reservation status.

# %%
class Ticket:
    def __init__(self, ticket_id, event_name, event_date, venue, seat_number, price):
        """
        Initializes a new Ticket instance.

        :param ticket_id: str - The unique identifier for the ticket.
        :param event_name: str - The name of the event.
        :param event_date: str - The date of the event (format should be consistent, e.g., "YYYY-MM-DD").
        :param venue: str - The venue of the event.
        :param seat_number: str - The seat number associated with the ticket.
        :param price: float - The price of the ticket.
        """
        self.ticket_id = ticket_id
        self.event_name = event_name
        self.event_date = event_date
        self.venue = venue
        self.seat_number = seat_number
        self.price = price
        self.is_reserved = False  # default is that the ticket is not reserved

    def reserve_ticket(self):
        """
        Marks the ticket as reserved if it is not already reserved.
        """
        if not self.is_reserved:
            self.is_reserved = True
            print(f"Ticket {self.ticket_id} has been reserved.")
        else:
            print(f"Ticket {self.ticket_id} is already reserved.")

    def cancel_reservation(self):
        """
        Cancels the reservation of the ticket if it is already reserved.
        """
        if self.is_reserved:
            self.is_reserved = False
            print(f"Reservation for ticket {self.ticket_id} has been canceled.")
        else:
            print(f"Ticket {self.ticket_id} is not reserved.")

    def display_ticket_info(self):
        """
        Displays the information about the ticket, including its attributes and reservation status.
        """
        reservation_status = "Reserved" if self.is_reserved else "Not Reserved"
        info = (
            f"Ticket ID: {self.ticket_id}\n"
            f"Event Name: {self.event_name}\n"
            f"Event Date: {self.event_date}\n"
            f"Venue: {self.venue}\n"
            f"Seat Number: {self.seat_number}\n"
            f"Price: ${self.price:.2f}\n"
            f"Reservation Status: {reservation_status}"
        )
        print(info)

# Example usage:
if __name__ == "__main__":
    ticket = Ticket("A123", "Concert of The Rolling Stones", "2024-06-15", "Madison Square Garden", "12B", 150.00)

    # Display ticket information
    ticket.display_ticket_info()

    # Reserve the ticket
    ticket.reserve_ticket()

    # Display ticket information again to see reservation status
    ticket.display_ticket_info()

    # Attempt to cancel the reservation
    ticket.cancel_reservation()

    # Display ticket information to confirm cancellation
    ticket.display_ticket_info()
# Out:
# Ticket ID: A123
# Event Name: Concert of The Rolling Stones
# Event Date: 2024-06-15
# Venue: Madison Square Garden
# Seat Number: 12B
# Price: $150.00
# Reservation Status: Not Reserved
# Ticket A123 has been reserved.
# Ticket ID: A123
# Event Name: Concert of The Rolling Stones
# Event Date: 2024-06-15
# Venue: Madison Square Garden
# Seat Number: 12B
# Price: $150.00
# Reservation Status: Reserved
# Reservation for ticket A123 has been canceled.
# Ticket ID: A123
# Event Name: Concert of The Rolling Stones
# Event Date: 2024-06-15
# Venue: Madison Square Garden
# Seat Number: 12B
# Price: $150.00
# Reservation Status: Not Reserved

# %% [markdown]
# 9. You are creating a shopping cart for an e-commerce website. Using OOP to model the "ShoppingCart" functionality the class should contain following attributes and methods:
# a. items: Represents the list of items in the shopping cart.
# The class also includes the following methods:
# a. add_item(self, item): Adds an item to the shopping cart by appending it to the list of items.
# b. remove_item(self, item): Removes an item from the shopping cart if it exists in the list.
# c. view_cart(self): Displays the items currently present in the shopping cart.
# d. clear_cart(self): Clears all items from the shopping cart by reassigning an
# empty list to the items attribute.

# %%
class ShoppingCart:
    def __init__(self):
        """
        Initializes a new ShoppingCart instance.
        """
        self.items = []

    def add_item(self, item):
        """
        Adds an item to the shopping cart.

        :param item: str - The name of the item to add.
        """
        self.items.append(item)
        print(f"'{item}' has been added to your shopping cart.")

    def remove_item(self, item):
        """
        Removes an item from the shopping cart if it exists.

        :param item: str - The name of the item to remove.
        """
        if item in self.items:
            self.items.remove(item)
            print(f"'{item}' has been removed from your shopping cart.")
        else:
            print(f"'{item}' not found in your shopping cart.")

    def view_cart(self):
        """
        Displays the items currently in the shopping cart.
        """
        if self.items:
            print("Items in your shopping cart:")
            for item in self.items:
                print(f"- {item}")
        else:
            print("Your shopping cart is empty.")

    def clear_cart(self):
        """
        Clears all items from the shopping cart.
        """
        self.items = []
        print("All items have been removed from your shopping cart.")

# Example usage:
if __name__ == "__main__":
    cart = ShoppingCart()

    # Adding items
    cart.add_item("Apple")
    cart.add_item("Banana")
    cart.add_item("Cherry")

    # Viewing cart
    cart.view_cart()

    # Removing an item
    cart.remove_item("Banana")
    
    # Viewing cart
    cart.view_cart()

    # Clearing the cart
    cart.clear_cart()

    # Viewing cart again
    cart.view_cart()
# Out:
# 'Apple' has been added to your shopping cart.
# 'Banana' has been added to your shopping cart.
# 'Cherry' has been added to your shopping cart.
# Items in your shopping cart:
# - Apple
# - Banana
# - Cherry
# 'Banana' has been removed from your shopping cart.
# Items in your shopping cart:
# - Apple
# - Cherry
# All items have been removed from your shopping cart.
# Your shopping cart is empty.

# %% [markdown]
# 10. Imagine a school management system. You have to design the "Student" class using OOP concepts.The “Student” class has the following attributes:
# a. name: Represents the name of the student.
# b. age: Represents the age of the student.
# c. grade: Represents the grade or class of the student.
# d. student_id: Represents the unique identifier for the student.
# e. attendance: Represents the attendance record of the student.
# The class should also include the following methods:
# a. update_attendance(self, date, status): Updates the attendance record of the
# student for a given date with the provided status (e.g., present or absent).
# b. get_attendance(self): Returns the attendance record of the student.
# c. get_average_attendance(self): Calculates and returns the average
# attendance percentage of the student based on their attendance record.

# %%
class Student:
    def __init__(self, name, age, grade, student_id):
        """
        Initializes a new Student instance.

        :param name: str - The name of the student.
        :param age: int - The age of the student.
        :param grade: str - The grade or class of the student.
        :param student_id: str - The unique identifier for the student.
        """
        self.name = name
        self.age = age
        self.grade = grade
        self.student_id = student_id
        self.attendance = {}  # Dictionary to store attendance records, date as key and status as value

    def update_attendance(self, date, status):
        """
        Updates the attendance record of the student for a given date.

        :param date: str - The date for the attendance record (format: YYYY-MM-DD).
        :param status: str - The attendance status ('present' or 'absent').
        """
        self.attendance[date] = status
        print(f"Attendance for {date} updated to '{status}' for student {self.name}.")

    def get_attendance(self):
        """
        Returns the attendance record of the student.

        :return: dict - The attendance record.
        """
        return self.attendance

    def get_average_attendance(self):
        """
        Calculates and returns the average attendance percentage.

        :return: float - The average attendance percentage.
        """
        total_days = len(self.attendance)
        if total_days == 0:
            return 0.0  # Avoid division by zero
        days_present = sum(1 for status in self.attendance.values() if status == 'present')
        return (days_present / total_days) * 100

# Example usage:
if __name__ == "__main__":
    student = Student("John Doe", 15, "10th Grade", "S1001")

    # Updating attendance
    student.update_attendance("2024-05-01", "present")
    student.update_attendance("2024-05-02", "absent")
    student.update_attendance("2024-05-03", "present")

    # Getting and printing attendance record
    print(student.get_attendance())

    # Calculating and printing average attendance
    average_attendance = student.get_average_attendance()
    print(f"Average Attendance: {average_attendance:.2f}%")
# Out:
# Attendance for 2024-05-01 updated to 'present' for student John Doe.
# Attendance for 2024-05-02 updated to 'absent' for student John Doe.
# Attendance for 2024-05-03 updated to 'present' for student John Doe.
# {'2024-05-01': 'present', '2024-05-02': 'absent', '2024-05-03': 'present'}
# Average Attendance: 66.67%
